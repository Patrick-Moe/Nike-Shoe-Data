# %% [markdown]
# <a href="https://colab.research.google.com/github/Patrick-Moe/Repository-1/blob/Excess/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7f8761aa-499b-49bd-8e46-b8001994da03" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f8761aa-499b-49bd-8e46-b8001994da03">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['StudentsPerformance.csv']))

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
for c in df.columns:
  df.rename(columns = {c:c.replace(' ', '_')}, inplace = True)
df.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
from scipy.stats import jarque_bera
from scipy.stats import normaltest
from scipy.stats import boxcox
from scipy.stats.mstats import winsorize

df["winsorized_math_score"] = winsorize(df["math_score"], (0, 0.10))
df["winsorized_reading_score"] = winsorize(df["reading_score"], (0, 0.10))
df["winsorized_writing_score"] = winsorize(df["writing_score"], (0, 0.10))

# Histograms of the original data
plt.subplot(3, 3, 1)
plt.hist(df["math_score"])
plt.title("histogram of math_score")

plt.subplot(3, 3, 2)
plt.hist(df["reading_score"])
plt.title("histogram of reading_score")

plt.subplot(3, 3, 3)
plt.hist(df["writing_score"])
plt.title("histogram of writing_score")

# Histograms of the winsorized data
plt.subplot(3, 3, 4)
plt.hist(df["winsorized_math_score"])
plt.title("win of math_score")

plt.subplot(3, 3, 5)
plt.hist(df["winsorized_reading_score"])
plt.title("win of reading_scores")

plt.subplot(3, 3, 6)
plt.hist(df["winsorized_writing_score"])
plt.title("wom of writing_score")

# Histograms of the log-transformed data
plt.subplot(3, 3, 7)
plt.hist(np.log(df["math_score"]))
plt.title("log of math_score")

plt.subplot(3, 3, 8)
plt.hist(np.log(df["reading_score"]))
plt.title("log of reading_score")

plt.subplot(3, 3, 9)
plt.hist(np.log(df["writing_score"]))
plt.title("log writing_score ")


plt.show()

# %%
print(df)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
jb_math=jarque_bera(df['math_score'])
jb_read=jarque_bera(df['reading_score'])
jb_write=jarque_bera(df['writing_score'])


norm_math=normaltest(df['math_score'])
norm_read = normaltest(df['reading_score'])
norm_write=normaltest(df['writing_score'])

print("Jarque-Bera test statistics is {0} and p value is {1}".format(jb_math[0], jb_math[1]))
print("Normality test statistics is {0} and p value is {1}".format(norm_math[0], norm_math[1]))

print("Jarque-Bera test statistics is {0} and p value is {1}".format(jb_read[0], jb_read[1]))
print("Normality test statistics is {0} and p value is {1}".format(norm_read[0], norm_read[1]))

print("Jarque-Bera test statistics is {0} and p value is {1}".format(jb_write[0], jb_write[1]))
print("Normality test statistics is {0} and p value is {1}".format(norm_write[0], norm_write[1]))
# Out:
# Jarque-Bera test statistics is 15.912256686712718 and p value is 0.00035050753868178273
# Normality test statistics is 15.408960513931822 and p value is 0.00045080293869937836
# Jarque-Bera test statistics is 11.383300575987937 and p value is 0.00337402026722133
# Normality test statistics is 11.11741279628622 and p value is 0.003853758403576582
# Jarque-Bera test statistics is 13.985094482572302 and p value is 0.0009187033894586782
# Normality test statistics is 13.606450837263859 and p value is 0.0011101885439899974

# %%
math_box = boxcox(df[df['math_score'] >0]['math_score'])
read_box = boxcox(df['reading_score'])
write_box = boxcox(df['writing_score'])

jb_b_math = jarque_bera(math_box)
jb_b_read = jarque_bera(read_box)
jb_b_write=jarque_bera(write_box)

norm_b_math = normaltest(math_box)
norm_b_read = normaltest(read_box)
norm_b_write=normaltest(write_box)

print("Jarque-Bera test statistics is {0} and p value is {1}".format(jb_b_math[0], jb_b_math[1]))
print("Normality test statistics is {0} and p value is {1}".format(norm_b_math[0], norm_b_math[1]))

print("Jarque-Bera test statistics is {0} and p value is {1}".format(jb_b_read[0], jb_b_read[1]))
print("Normality test statistics is {0} and p value is {1}".format(norm_b_read[0], norm_b_read[1]))

print("Jarque-Bera test statistics is {0} and p value is {1}".format(jb_b_write[0], jb_b_write[1]))
print("Normality test statistics is {0} and p value is {1}".format(norm_b_write[0], norm_b_write[1]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-5c007c27ef2b> in <cell line: 5>()
#       3 write_box = boxcox(df['writing_score'])
#       4
# ----> 5 jb_b_math = jarque_bera(math_box)
#       6 jb_b_read = jarque_bera(read_box)
#       7 jb_b_write=jarque_bera(write_box)
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py in axis_nan_policy_wrapper(***failed resolving arguments***)
#     500                 if sentinel:
#     501                     samples = _remove_sentinel(samples, paired, sentinel)
# --> 502                 res = hypotest_fun_out(*samples, **kwds)
#     503                 res = result_to_tuple(res)
#     504                 res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py in jarque_bera(x, axis)
# ...

# %%
exam_score = (df['math_score'] + df['reading_score'] + df['writing_score'])/3

plt.hist(exam_score)
plt.title("histogram of exam score")
plt.show()

jb_exam = jarque_bera(exam_score)
norm_exam = normaltest(exam_score)
print("Jarque-Bera test statistics is {0} and p value is {1}".format(jb_exam[0], jb_exam[1]))
print("Normality test statistics is {0} and p value is {1}".format(norm_exam[0], norm_exam[1]))
# Out:
# Jarque-Bera test statistics is 15.453387913085383 and p value is 0.0004408993426440262
# Normality test statistics is 15.186721327231322 and p value is 0.0005037851534494478

# %%
exams_boxcox,_ = boxcox(exam_score)

plt.hist(exams_boxcox)
plt.title("histogram of exam score (box-cox transformed)")
plt.show()

jb_stats = jarque_bera(exams_boxcox)
norm_stats = normaltest(exams_boxcox)

print("Jarque-Bera test statistics is {0} and p value is {1}".format(jb_stats[0], jb_stats[1]))
print("Normality test statistics is {0} and p value is {1}".format(norm_stats[0], norm_stats[1]))
# Out:
# Jarque-Bera test statistics is 2.4353989331279235 and p value is 0.29591013563984125
# Normality test statistics is 2.779857602227654 and p value is 0.24909303914726255

# %%
education_df = df
education_df["exam_score"] = exam_score

plt.figure(figsize=(18, 10))

plt.subplot(2, 3, 1)
plt.bar(education_df.groupby("race/ethnicity")
        ["exam_score"].mean().index, education_df.groupby("race/ethnicity")["exam_score"].mean())

plt.title("average exam scores wrt. race/ethnicity")
plt.xticks(rotation="vertical")

plt.subplot(2, 3, 2)
plt.bar(education_df.groupby("gender")
        ["exam_score"].mean().index, education_df.groupby("gender")["exam_score"].mean())

plt.title("average exam scores wrt. gender")
plt.xticks(rotation="vertical")

plt.subplot(2, 3, 3)
plt.bar(education_df.groupby("parental_level_of_education")
        ["exam_score"].mean().index, education_df.groupby("parental_level_of_education")["exam_score"].mean())

plt.title("average exam scores wrt. parental level of education")
plt.xticks(rotation="vertical")

plt.subplot(2, 3, 4)
plt.bar(education_df.groupby("lunch")
        ["exam_score"].mean().index, education_df.groupby("lunch")["exam_score"].mean())

plt.title("average exam scores wrt. lunch")
plt.xticks(rotation="vertical")

plt.subplot(2, 3, 5)
plt.bar(education_df.groupby("test_preparation_course")
        ["exam_score"].mean().index, education_df.groupby("test_preparation_course")["exam_score"].mean())

plt.title("average exam scores wrt. test preparation course")
plt.xticks(rotation="vertical")

plt.tight_layout()
plt.show()

#data ascedes from A to E
#women score slightly higher
#masters degree leads to higher exam scores. Doesnt explain why some highschool is slightly higher then full highschool
#standard lunch is slightly higher
#prep courses help with exam scores
